# %% [markdown]
# <a id = "descente_maximale"></a>
# ### descente_maximale
#
# On considère des jetons arrangés en triangle comme ci-dessous. Déterminez un algorithme - qui ne consiste pas à tester tous les chemins possibles ! - permettant d'obtenir la descente du sommet vers la base totalisant le maximum de points.

# %%
from affichages.descente_maximale import Dessin
d = Dessin()

# %% [markdown]
# Voici un exemple de descente :

# %%
d.exemple_de_descente()
